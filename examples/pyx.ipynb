# %%
using PyX

g = graph.graphxy(width=8)
plot(g, graph_data_function("y(x)=sin(x)/x", min=-15, max=15))
g
# Out:
# PyX.PyxCanvas(PyObject <pyx.graph.graph.graphxy object at 0x7f57f31ff4a8>)

# %%
1+1
# Out:
# 2
